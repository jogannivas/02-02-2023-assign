# %%
import pymongo

client = pymongo.MongoClient("mongodb+srv://jogannivas:Yodhha12345@cluster0.1y4zc2o.mongodb.net/?retryWrites=true&w=majority")
db = client.test

# %%
pip install pymongo
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
db
# Out:
# Database(MongoClient(host=['ac-khckh7p-shard-00-01.1y4zc2o.mongodb.net:27017', 'ac-khckh7p-shard-00-02.1y4zc2o.mongodb.net:27017', 'ac-khckh7p-shard-00-00.1y4zc2o.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', authsource='admin', replicaset='atlas-10pxfp-shard-0', tls=True), 'test')

# %%
client = pymongo.MongoClient("mongodb+srv://jogannivas:Yodhha12345@cluster0.1y4zc2o.mongodb.net/?retryWrites=true&w=majority")

# %%
db=client['joga']

# %%
data={"name":'jogannivas',
     "class": 'Data Science Maasters',
      "time": "flexi"}

# %%
coll_jogannivas= db["my_record"]

# %%
coll_jogannivas.insert_one(data)
# Out:
# ---------------------------------------------------------------------------
# OperationFailure                          Traceback (most recent call last)
# Cell In [18], line 1
# ----> 1 coll_jogannivas.insert_one(data)
#
# File /opt/conda/lib/python3.10/site-packages/pymongo/collection.py:628, in Collection.insert_one(self, document, bypass_document_validation, session, comment)
#     624     document["_id"] = ObjectId()  # type: ignore[index]
#     626 write_concern = self._write_concern_for(session)
#     627 return InsertOneResult(
# --> 628     self._insert_one(
#     629         document,
#     630         ordered=True,
#     631         write_concern=write_concern,
#     632         op_id=None,
#     633         bypass_doc_val=bypass_document_validation,
#     634         session=session,
#     635         comment=comment,
#     636     ),
#     637     write_concern.acknowledged,
#     638 )
#
# ...

# %%
data01={"name":'jogannivas1',
     "class": 'Data Science Maasters1',
      "time": "flexi1"}

# %%
coll_joga.insert_one(data01)
# Out:
# ---------------------------------------------------------------------------
# OperationFailure                          Traceback (most recent call last)
# Cell In [12], line 1
# ----> 1 coll_joga.insert_one(data01)
#
# File /opt/conda/lib/python3.10/site-packages/pymongo/collection.py:628, in Collection.insert_one(self, document, bypass_document_validation, session, comment)
#     624     document["_id"] = ObjectId()  # type: ignore[index]
#     626 write_concern = self._write_concern_for(session)
#     627 return InsertOneResult(
# --> 628     self._insert_one(
#     629         document,
#     630         ordered=True,
#     631         write_concern=write_concern,
#     632         op_id=None,
#     633         bypass_doc_val=bypass_document_validation,
#     634         session=session,
#     635         comment=comment,
#     636     ),
#     637     write_concern.acknowledged,
#     638 )
#
# ...

# %%
coll_jogannivas.find_one()
# Out:
# ---------------------------------------------------------------------------
# OperationFailure                          Traceback (most recent call last)
# Cell In [30], line 1
# ----> 1 coll_jogannivas.find_one()
#
# File /opt/conda/lib/python3.10/site-packages/pymongo/collection.py:1459, in Collection.find_one(self, filter, *args, **kwargs)
#    1457     filter = {"_id": filter}
#    1458 cursor = self.find(filter, *args, **kwargs)
# -> 1459 for result in cursor.limit(-1):
#    1460     return result
#    1461 return None
#
# File /opt/conda/lib/python3.10/site-packages/pymongo/cursor.py:1248, in Cursor.next(self)
#    1246 if self.__empty:
#    1247     raise StopIteration
# -> 1248 if len(self.__data) or self._refresh():
#    1249     return self.__data.popleft()
#    1250 else:
#
# File /opt/conda/lib/python3.10/site-packages/pymongo/cursor.py:1165, in Cursor._refresh(self)
#    1143         raise InvalidOperation(
# ...
